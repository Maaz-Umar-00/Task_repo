# %%
import os
import io
import string
from tqdm import tqdm
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

import nltk
from nltk.corpus import stopwords

from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %% [markdown]
# ### Read data

# %%
data = pd.read_csv('Data/IMDB_Dataset.csv')

# %%
data.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %% [markdown]
# ### Convert sentiment column to int

# %%
data['sentiment'] = data['sentiment'].map({'positive': 1, 'negative': 0})

# %% [markdown]
# ### Split data

# %%
# Shuffle the DataFrame
shuffled_data = data.sample(frac=1, random_state=2023)  

train_size = 0.8  # 80% for training, 20% for testing
train_data, test_data = train_test_split(shuffled_data, train_size=train_size, random_state=2023)

# %%
print(f'Train shappe: {train_data.shape}')
print(f'Test shappe: {test_data.shape}')
# Out:
# Train shappe: (40000, 2)
# Test shappe: (10000, 2)

# %%
X_train = train_data['review']
y_train = train_data['sentiment']

X_test = test_data['review']
y_test = test_data['sentiment']

# %% [markdown]
# ### Preprocessing - Clean text
# * Remove stopwords
# * Remove punctuations
# * Remove html tags

# %%
# using stopwords from nltk
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/gcerri/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
table = str.maketrans('', '', string.punctuation)

# %%
X_train_cleaned = []

for item in tqdm(X_train):
    sentence = str(item).lower()
    # if we have 2 joined words 
    sentence = sentence.replace(",", " , ")
    sentence = sentence.replace(".", " . ")
    sentence = sentence.replace("-", " - ")
    sentence = sentence.replace("/", " / ")
    # remove <br> tag
    soup = BeautifulSoup(sentence)
    sentence = soup.get_text()
    # remove stop words and punctuations
    words = sentence.split()
    filtered_sentence = ""
    for word in words:
        word = word.translate(table) # remove all punctuations
        if word not in stop_words:
            filtered_sentence += word + ' '
    
    X_train_cleaned.append(filtered_sentence.strip())
# Out:
#   2%|▋                                    | 801/40000 [00:00<00:14, 2667.58it/s]/var/folders/mq/cmjp1vmd5f1fdgxg3fzz2rb00000gq/T/ipykernel_92405/3557040181.py:11: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(sentence)
# 100%|███████████████████████████████████| 40000/40000 [00:17<00:00, 2278.29it/s]

# %% [markdown]
# ### See sentences length distribution

# %%
sentence_lengths = [len(sentence) for sentence in X_train_cleaned]
sorted_lengths = sorted(sentence_lengths)

x_values = list(range(1, len(X_train_cleaned) + 1))

# Creiamo il grafico
plt.figure(figsize=(8, 5))  
plt.plot(x_values, sorted_lengths, marker='.', linestyle='-')  
plt.title('Sentence Length Distribution')
plt.xlabel('Sentence Index')
plt.ylabel('Sentence Length')
plt.grid(True)  
plt.tight_layout()  
plt.show()

# %% [markdown]
# ### Zoom on the left part

# %%
# Creiamo il grafico
plt.figure(figsize=(6, 3))  
plt.plot(x_values, sorted_lengths, marker='.', linestyle='-')  
plt.title('Sentence Length Distribution')
plt.xlabel('Sentence Index')
plt.ylabel('Sentence Length')
plt.grid(True)  
plt.tight_layout()
plt.ylim(0, 3000)
plt.show()

# %% [markdown]
# **most of the sentences have less than 2000 words and 1000 words**

# %% [markdown]
# ### Check the total set of words

# %%
all_words = [word for sentence in X_train_cleaned for word in sentence.split()]

# Calculate the vocabulary size (number of unique words)
total_vocab_size = len(set(all_words))

print("Total Vocabulary Size:", total_vocab_size)
# Out:
# Total Vocabulary Size: 110114

# %% [markdown]
# ### Tokenization

# %%
vocab_size = 50000
max_length = 2000
trunc_type='post'
padding_type='post'
oov_tok = ""

# %%
tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(X_train_cleaned)

# %%
word_index = tokenizer.word_index

training_sequences = tokenizer.texts_to_sequences(X_train_cleaned)
training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(X_test)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# %% [markdown]
# ### WordCloud

# %%
wordcloud = WordCloud(width=800, height=400, background_color='white')

# Generate the word cloud
word_counts = tokenizer.word_counts
wordcloud.generate_from_frequencies(word_counts)
wordcloud.to_file("doc/header.png")

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')

plt.show()

# %% [markdown]
# seems we have done a good cleaning

# %% [markdown]
# ### Split the train into train and validation
# Using 80% for train and 20% for test

# %%
training_padded, validation_padded, y_train, y_valid = train_test_split(training_padded, y_train, test_size=0.2, random_state=2023)

# %%
training_padded = np.array(training_padded)
training_labels = np.array(y_train)

validation_padded = np.array(validation_padded)
validation_labels = np.array(y_valid)

testing_padded = np.array(testing_padded)
testing_labels = np.array(y_test)

# %%
print(f'Train shappe: {train_data.shape}')
print(f'Validation shappe: {validation_padded.shape}')
print(f'Test shappe: {test_data.shape}')
# Out:
# Train shappe: (40000, 2)
# Validation shappe: (8000, 2000)
# Test shappe: (10000, 2)

# %% [markdown]
# ### Define the neural network

# %%
embedding_dim = round(vocab_size ** 0.25) # use the fourth root of the vocab size
l2_regularization = 0.01 # tends to amplify differences between nonzero values and zero or close-tozero ones

# %%
def create_model(vocab_size, embedding_dim):
    model = tf.keras.Sequential([
            tf.keras.layers.Embedding(vocab_size, embedding_dim), # turns positive integers into dense vectors of fixed size
            tf.keras.layers.GlobalAveragePooling1D(),
            tf.keras.layers.Dense(24, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(l2_regularization)),
            tf.keras.layers.Dropout(.25),
            tf.keras.layers.Dense(1, activation='sigmoid')
        ])

    adam = tf.keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, amsgrad=False)
    
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])

    return model

# %%
model = create_model(vocab_size, embedding_dim)
# Display the model's architecture
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, None, 15)          750000
#
#  global_average_pooling1d_1  (None, 15)                0
#   (GlobalAveragePooling1D)
#
#  dense_2 (Dense)             (None, 24)                384
#
#  dropout_1 (Dropout)         (None, 24)                0
#
#  dense_3 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 750409 (2.86 MB)
# Trainable params: 750409 (2.86 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
checkpoint_path = "training/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# %%
# Create a callback that saves the model's weights every 5 epochs
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1,
                                                 period=5)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
num_epochs = 100
history = model.fit(training_padded, 
                    training_labels, 
                    epochs=num_epochs, 
                    validation_data=(validation_padded, validation_labels), 
                    verbose=2,
                    callbacks=[cp_callback])
# Out:
# Epoch 1/100
# 1000/1000 - 9s - loss: 0.5882 - accuracy: 0.8079 - val_loss: 0.5829 - val_accuracy: 0.8474 - 9s/epoch - 9ms/step
# Epoch 2/100
# 1000/1000 - 15s - loss: 0.5815 - accuracy: 0.8104 - val_loss: 0.5764 - val_accuracy: 0.8499 - 15s/epoch - 15ms/step
# Epoch 3/100
# 1000/1000 - 16s - loss: 0.5754 - accuracy: 0.8131 - val_loss: 0.5700 - val_accuracy: 0.8516 - 16s/epoch - 16ms/step
# Epoch 4/100
# 1000/1000 - 15s - loss: 0.5682 - accuracy: 0.8160 - val_loss: 0.5633 - val_accuracy: 0.8510 - 15s/epoch - 15ms/step
# Epoch 5/100
#
# Epoch 5: saving model to training/cp-0005.ckpt
# 1000/1000 - 11s - loss: 0.5637 - accuracy: 0.8166 - val_loss: 0.5573 - val_accuracy: 0.8500 - 11s/epoch - 11ms/step
# Epoch 6/100
# 1000/1000 - 13s - loss: 0.5564 - accuracy: 0.8235 - val_loss: 0.5512 - val_accuracy: 0.8570 - 13s/epoch - 13ms/step
# Epoch 7/100
# 1000/1000 - 14s - loss: 0.5509 - accuracy: 0.8239 - val_loss: 0.5454 - val_accuracy: 0.8499 - 14s/epoch - 14ms/step
# Epoch 8/100
# 1000/1000 - 16s - loss: 0.5454 - accuracy: 0.8245 - val_loss: 0.5394 - val_accuracy: 0.8589 - 16s/epoch - 16ms/step
# Epoch 9/100
# 1000/1000 - 14s - loss: 0.5390 - accuracy: 0.8288 - val_loss: 0.5344 - val_accuracy: 0.8604 - 14s/epoch - 14ms/step
# Epoch 10/100
#
# Epoch 10: saving model to training/cp-0010.ckpt
# 1000/1000 - 14s - loss: 0.5325 - accuracy: 0.8323 - val_loss: 0.5278 - val_accuracy: 0.8602 - 14s/epoch - 14ms/step
# Epoch 11/100
# 1000/1000 - 15s - loss: 0.5275 - accuracy: 0.8314 - val_loss: 0.5224 - val_accuracy: 0.8611 - 15s/epoch - 15ms/step
# Epoch 12/100
# 1000/1000 - 15s - loss: 0.5229 - accuracy: 0.8336 - val_loss: 0.5172 - val_accuracy: 0.8589 - 15s/epoch - 15ms/step
# Epoch 13/100
# 1000/1000 - 16s - loss: 0.5163 - accuracy: 0.8366 - val_loss: 0.5119 - val_accuracy: 0.8666 - 16s/epoch - 16ms/step
# Epoch 14/100
# 1000/1000 - 14s - loss: 0.5120 - accuracy: 0.8404 - val_loss: 0.5068 - val_accuracy: 0.8629 - 14s/epoch - 14ms/step
# Epoch 15/100
#
# Epoch 15: saving model to training/cp-0015.ckpt
# 1000/1000 - 16s - loss: 0.5058 - accuracy: 0.8433 - val_loss: 0.5018 - val_accuracy: 0.8637 - 16s/epoch - 16ms/step
# Epoch 16/100
# 1000/1000 - 15s - loss: 0.5011 - accuracy: 0.8454 - val_loss: 0.4969 - val_accuracy: 0.8648 - 15s/epoch - 15ms/step
# Epoch 17/100
# 1000/1000 - 13s - loss: 0.4955 - accuracy: 0.8499 - val_loss: 0.4920 - val_accuracy: 0.8690 - 13s/epoch - 13ms/step
# Epoch 18/100
# 1000/1000 - 15s - loss: 0.4916 - accuracy: 0.8466 - val_loss: 0.4875 - val_accuracy: 0.8690 - 15s/epoch - 15ms/step
# Epoch 19/100
# 1000/1000 - 13s - loss: 0.4859 - accuracy: 0.8521 - val_loss: 0.4830 - val_accuracy: 0.8690 - 13s/epoch - 13ms/step
# Epoch 20/100
#
# Epoch 20: saving model to training/cp-0020.ckpt
# 1000/1000 - 12s - loss: 0.4812 - accuracy: 0.8503 - val_loss: 0.4791 - val_accuracy: 0.8721 - 12s/epoch - 12ms/step
# Epoch 21/100
# 1000/1000 - 12s - loss: 0.4770 - accuracy: 0.8543 - val_loss: 0.4762 - val_accuracy: 0.8725 - 12s/epoch - 12ms/step
# Epoch 22/100
# 1000/1000 - 11s - loss: 0.4724 - accuracy: 0.8580 - val_loss: 0.4701 - val_accuracy: 0.8727 - 11s/epoch - 11ms/step
# Epoch 23/100
# 1000/1000 - 11s - loss: 0.4672 - accuracy: 0.8599 - val_loss: 0.4660 - val_accuracy: 0.8708 - 11s/epoch - 11ms/step
# Epoch 24/100
# 1000/1000 - 11s - loss: 0.4624 - accuracy: 0.8618 - val_loss: 0.4619 - val_accuracy: 0.8725 - 11s/epoch - 11ms/step
# Epoch 25/100
#
# Epoch 25: saving model to training/cp-0025.ckpt
# 1000/1000 - 11s - loss: 0.4602 - accuracy: 0.8604 - val_loss: 0.4584 - val_accuracy: 0.8755 - 11s/epoch - 11ms/step
# Epoch 26/100
# 1000/1000 - 12s - loss: 0.4544 - accuracy: 0.8649 - val_loss: 0.4543 - val_accuracy: 0.8763 - 12s/epoch - 12ms/step
# Epoch 27/100
# 1000/1000 - 11s - loss: 0.4507 - accuracy: 0.8653 - val_loss: 0.4508 - val_accuracy: 0.8739 - 11s/epoch - 11ms/step
# Epoch 28/100
# 1000/1000 - 11s - loss: 0.4465 - accuracy: 0.8653 - val_loss: 0.4467 - val_accuracy: 0.8754 - 11s/epoch - 11ms/step
# Epoch 29/100
# 1000/1000 - 11s - loss: 0.4431 - accuracy: 0.8687 - val_loss: 0.4434 - val_accuracy: 0.8752 - 11s/epoch - 11ms/step
# Epoch 30/100
#
# Epoch 30: saving model to training/cp-0030.ckpt
# 1000/1000 - 11s - loss: 0.4381 - accuracy: 0.8708 - val_loss: 0.4395 - val_accuracy: 0.8784 - 11s/epoch - 11ms/step
# Epoch 31/100
# 1000/1000 - 12s - loss: 0.4334 - accuracy: 0.8722 - val_loss: 0.4359 - val_accuracy: 0.8785 - 12s/epoch - 12ms/step
# Epoch 32/100
# 1000/1000 - 11s - loss: 0.4297 - accuracy: 0.8719 - val_loss: 0.4327 - val_accuracy: 0.8780 - 11s/epoch - 11ms/step
# Epoch 33/100
# 1000/1000 - 11s - loss: 0.4273 - accuracy: 0.8742 - val_loss: 0.4296 - val_accuracy: 0.8794 - 11s/epoch - 11ms/step
# Epoch 34/100
# 1000/1000 - 11s - loss: 0.4221 - accuracy: 0.8770 - val_loss: 0.4272 - val_accuracy: 0.8810 - 11s/epoch - 11ms/step
# Epoch 35/100
#
# Epoch 35: saving model to training/cp-0035.ckpt
# 1000/1000 - 11s - loss: 0.4189 - accuracy: 0.8788 - val_loss: 0.4231 - val_accuracy: 0.8815 - 11s/epoch - 11ms/step
# Epoch 36/100
# 1000/1000 - 12s - loss: 0.4171 - accuracy: 0.8764 - val_loss: 0.4207 - val_accuracy: 0.8796 - 12s/epoch - 12ms/step
# Epoch 37/100
# 1000/1000 - 11s - loss: 0.4134 - accuracy: 0.8769 - val_loss: 0.4178 - val_accuracy: 0.8827 - 11s/epoch - 11ms/step
# Epoch 38/100
# 1000/1000 - 11s - loss: 0.4085 - accuracy: 0.8803 - val_loss: 0.4143 - val_accuracy: 0.8834 - 11s/epoch - 11ms/step
# Epoch 39/100
# 1000/1000 - 11s - loss: 0.4049 - accuracy: 0.8810 - val_loss: 0.4114 - val_accuracy: 0.8830 - 11s/epoch - 11ms/step
# Epoch 40/100
#
# Epoch 40: saving model to training/cp-0040.ckpt
# 1000/1000 - 11s - loss: 0.4027 - accuracy: 0.8815 - val_loss: 0.4093 - val_accuracy: 0.8850 - 11s/epoch - 11ms/step
# Epoch 41/100
# 1000/1000 - 11s - loss: 0.4002 - accuracy: 0.8833 - val_loss: 0.4063 - val_accuracy: 0.8851 - 11s/epoch - 11ms/step
# Epoch 42/100
# 1000/1000 - 10s - loss: 0.3959 - accuracy: 0.8841 - val_loss: 0.4035 - val_accuracy: 0.8855 - 10s/epoch - 10ms/step
# Epoch 43/100
# 1000/1000 - 10s - loss: 0.3934 - accuracy: 0.8867 - val_loss: 0.4008 - val_accuracy: 0.8855 - 10s/epoch - 10ms/step
# Epoch 44/100
# 1000/1000 - 11s - loss: 0.3906 - accuracy: 0.8856 - val_loss: 0.3982 - val_accuracy: 0.8869 - 11s/epoch - 11ms/step
# Epoch 45/100
#
# Epoch 45: saving model to training/cp-0045.ckpt
# 1000/1000 - 10s - loss: 0.3882 - accuracy: 0.8851 - val_loss: 0.3961 - val_accuracy: 0.8867 - 10s/epoch - 10ms/step
# Epoch 46/100
# 1000/1000 - 11s - loss: 0.3838 - accuracy: 0.8889 - val_loss: 0.3937 - val_accuracy: 0.8870 - 11s/epoch - 11ms/step
# Epoch 47/100
# 1000/1000 - 10s - loss: 0.3821 - accuracy: 0.8889 - val_loss: 0.3910 - val_accuracy: 0.8884 - 10s/epoch - 10ms/step
# Epoch 48/100
# 1000/1000 - 10s - loss: 0.3797 - accuracy: 0.8891 - val_loss: 0.3886 - val_accuracy: 0.8896 - 10s/epoch - 10ms/step
# Epoch 49/100
# 1000/1000 - 10s - loss: 0.3761 - accuracy: 0.8913 - val_loss: 0.3872 - val_accuracy: 0.8859 - 10s/epoch - 10ms/step
# Epoch 50/100
#
# Epoch 50: saving model to training/cp-0050.ckpt
# 1000/1000 - 10s - loss: 0.3734 - accuracy: 0.8925 - val_loss: 0.3841 - val_accuracy: 0.8896 - 10s/epoch - 10ms/step
# Epoch 51/100
# 1000/1000 - 12s - loss: 0.3695 - accuracy: 0.8936 - val_loss: 0.3818 - val_accuracy: 0.8910 - 12s/epoch - 12ms/step
# Epoch 52/100
# 1000/1000 - 10s - loss: 0.3665 - accuracy: 0.8931 - val_loss: 0.3796 - val_accuracy: 0.8909 - 10s/epoch - 10ms/step
# Epoch 53/100
# 1000/1000 - 10s - loss: 0.3627 - accuracy: 0.8955 - val_loss: 0.3800 - val_accuracy: 0.8855 - 10s/epoch - 10ms/step
# Epoch 54/100
# 1000/1000 - 10s - loss: 0.3629 - accuracy: 0.8935 - val_loss: 0.3764 - val_accuracy: 0.8910 - 10s/epoch - 10ms/step
# Epoch 55/100
#
# Epoch 55: saving model to training/cp-0055.ckpt
# 1000/1000 - 10s - loss: 0.3601 - accuracy: 0.8960 - val_loss: 0.3739 - val_accuracy: 0.8920 - 10s/epoch - 10ms/step
# Epoch 56/100
# 1000/1000 - 11s - loss: 0.3570 - accuracy: 0.8970 - val_loss: 0.3720 - val_accuracy: 0.8924 - 11s/epoch - 11ms/step
# Epoch 57/100
# 1000/1000 - 10s - loss: 0.3548 - accuracy: 0.8969 - val_loss: 0.3700 - val_accuracy: 0.8930 - 10s/epoch - 10ms/step
# Epoch 58/100
# 1000/1000 - 10s - loss: 0.3533 - accuracy: 0.8971 - val_loss: 0.3681 - val_accuracy: 0.8932 - 10s/epoch - 10ms/step
# Epoch 59/100
# 1000/1000 - 10s - loss: 0.3521 - accuracy: 0.8979 - val_loss: 0.3666 - val_accuracy: 0.8932 - 10s/epoch - 10ms/step
# Epoch 60/100
#
# Epoch 60: saving model to training/cp-0060.ckpt
# 1000/1000 - 10s - loss: 0.3487 - accuracy: 0.8994 - val_loss: 0.3649 - val_accuracy: 0.8932 - 10s/epoch - 10ms/step
# Epoch 61/100
# 1000/1000 - 11s - loss: 0.3456 - accuracy: 0.9003 - val_loss: 0.3628 - val_accuracy: 0.8944 - 11s/epoch - 11ms/step
# Epoch 62/100
# 1000/1000 - 10s - loss: 0.3433 - accuracy: 0.9010 - val_loss: 0.3612 - val_accuracy: 0.8946 - 10s/epoch - 10ms/step
# Epoch 63/100
# 1000/1000 - 10s - loss: 0.3423 - accuracy: 0.9005 - val_loss: 0.3610 - val_accuracy: 0.8905 - 10s/epoch - 10ms/step
# Epoch 64/100
# 1000/1000 - 11s - loss: 0.3396 - accuracy: 0.9025 - val_loss: 0.3584 - val_accuracy: 0.8951 - 11s/epoch - 11ms/step
# Epoch 65/100
#
# Epoch 65: saving model to training/cp-0065.ckpt
# 1000/1000 - 10s - loss: 0.3369 - accuracy: 0.9031 - val_loss: 0.3563 - val_accuracy: 0.8957 - 10s/epoch - 10ms/step
# Epoch 66/100
# 1000/1000 - 11s - loss: 0.3358 - accuracy: 0.9022 - val_loss: 0.3551 - val_accuracy: 0.8953 - 11s/epoch - 11ms/step
# Epoch 67/100
# 1000/1000 - 10s - loss: 0.3332 - accuracy: 0.9042 - val_loss: 0.3531 - val_accuracy: 0.8963 - 10s/epoch - 10ms/step
# Epoch 68/100
# 1000/1000 - 10s - loss: 0.3321 - accuracy: 0.9039 - val_loss: 0.3521 - val_accuracy: 0.8965 - 10s/epoch - 10ms/step
# Epoch 69/100
# 1000/1000 - 11s - loss: 0.3298 - accuracy: 0.9061 - val_loss: 0.3508 - val_accuracy: 0.8963 - 11s/epoch - 11ms/step
# Epoch 70/100
#
# Epoch 70: saving model to training/cp-0070.ckpt
# 1000/1000 - 10s - loss: 0.3273 - accuracy: 0.9048 - val_loss: 0.3490 - val_accuracy: 0.8976 - 10s/epoch - 10ms/step
# Epoch 71/100
# 1000/1000 - 11s - loss: 0.3262 - accuracy: 0.9043 - val_loss: 0.3480 - val_accuracy: 0.8970 - 11s/epoch - 11ms/step
# Epoch 72/100
# 1000/1000 - 11s - loss: 0.3229 - accuracy: 0.9064 - val_loss: 0.3469 - val_accuracy: 0.8964 - 11s/epoch - 11ms/step
# Epoch 73/100
# 1000/1000 - 11s - loss: 0.3226 - accuracy: 0.9063 - val_loss: 0.3449 - val_accuracy: 0.8975 - 11s/epoch - 11ms/step
# Epoch 74/100
# 1000/1000 - 10s - loss: 0.3211 - accuracy: 0.9089 - val_loss: 0.3440 - val_accuracy: 0.8974 - 10s/epoch - 10ms/step
# Epoch 75/100
#
# Epoch 75: saving model to training/cp-0075.ckpt
# 1000/1000 - 11s - loss: 0.3181 - accuracy: 0.9088 - val_loss: 0.3423 - val_accuracy: 0.8994 - 11s/epoch - 11ms/step
# Epoch 76/100
# 1000/1000 - 11s - loss: 0.3183 - accuracy: 0.9091 - val_loss: 0.3415 - val_accuracy: 0.8990 - 11s/epoch - 11ms/step
# Epoch 77/100
# 1000/1000 - 12s - loss: 0.3162 - accuracy: 0.9084 - val_loss: 0.3401 - val_accuracy: 0.8980 - 12s/epoch - 12ms/step
# Epoch 78/100
# 1000/1000 - 11s - loss: 0.3130 - accuracy: 0.9090 - val_loss: 0.3388 - val_accuracy: 0.8984 - 11s/epoch - 11ms/step
# Epoch 79/100
# 1000/1000 - 11s - loss: 0.3117 - accuracy: 0.9098 - val_loss: 0.3381 - val_accuracy: 0.8971 - 11s/epoch - 11ms/step
# Epoch 80/100
#
# Epoch 80: saving model to training/cp-0080.ckpt
# 1000/1000 - 12s - loss: 0.3103 - accuracy: 0.9097 - val_loss: 0.3365 - val_accuracy: 0.8988 - 12s/epoch - 12ms/step
# Epoch 81/100
# 1000/1000 - 11s - loss: 0.3078 - accuracy: 0.9126 - val_loss: 0.3356 - val_accuracy: 0.8988 - 11s/epoch - 11ms/step
# Epoch 82/100
# 1000/1000 - 11s - loss: 0.3068 - accuracy: 0.9115 - val_loss: 0.3357 - val_accuracy: 0.8984 - 11s/epoch - 11ms/step
# Epoch 83/100
# 1000/1000 - 11s - loss: 0.3048 - accuracy: 0.9134 - val_loss: 0.3330 - val_accuracy: 0.8996 - 11s/epoch - 11ms/step
# Epoch 84/100
# 1000/1000 - 14s - loss: 0.3038 - accuracy: 0.9119 - val_loss: 0.3327 - val_accuracy: 0.8980 - 14s/epoch - 14ms/step
# Epoch 85/100
#
# Epoch 85: saving model to training/cp-0085.ckpt
# 1000/1000 - 12s - loss: 0.3020 - accuracy: 0.9151 - val_loss: 0.3308 - val_accuracy: 0.9010 - 12s/epoch - 12ms/step
# Epoch 86/100
# 1000/1000 - 12s - loss: 0.3012 - accuracy: 0.9132 - val_loss: 0.3299 - val_accuracy: 0.9011 - 12s/epoch - 12ms/step
# Epoch 87/100
# 1000/1000 - 10s - loss: 0.2983 - accuracy: 0.9149 - val_loss: 0.3293 - val_accuracy: 0.8995 - 10s/epoch - 10ms/step
# Epoch 88/100
# 1000/1000 - 10s - loss: 0.2963 - accuracy: 0.9153 - val_loss: 0.3281 - val_accuracy: 0.9003 - 10s/epoch - 10ms/step
# Epoch 89/100
# 1000/1000 - 10s - loss: 0.2956 - accuracy: 0.9160 - val_loss: 0.3269 - val_accuracy: 0.9020 - 10s/epoch - 10ms/step
# Epoch 90/100
#
# Epoch 90: saving model to training/cp-0090.ckpt
# 1000/1000 - 10s - loss: 0.2956 - accuracy: 0.9144 - val_loss: 0.3262 - val_accuracy: 0.9007 - 10s/epoch - 10ms/step
# Epoch 91/100
# 1000/1000 - 11s - loss: 0.2933 - accuracy: 0.9165 - val_loss: 0.3252 - val_accuracy: 0.9024 - 11s/epoch - 11ms/step
# Epoch 92/100
# 1000/1000 - 10s - loss: 0.2924 - accuracy: 0.9160 - val_loss: 0.3242 - val_accuracy: 0.9010 - 10s/epoch - 10ms/step
# Epoch 93/100
# 1000/1000 - 10s - loss: 0.2907 - accuracy: 0.9167 - val_loss: 0.3234 - val_accuracy: 0.9019 - 10s/epoch - 10ms/step
# Epoch 94/100
# 1000/1000 - 11s - loss: 0.2883 - accuracy: 0.9175 - val_loss: 0.3225 - val_accuracy: 0.9018 - 11s/epoch - 11ms/step
# Epoch 95/100
#
# Epoch 95: saving model to training/cp-0095.ckpt
# 1000/1000 - 10s - loss: 0.2873 - accuracy: 0.9188 - val_loss: 0.3216 - val_accuracy: 0.9021 - 10s/epoch - 10ms/step
# Epoch 96/100
# 1000/1000 - 11s - loss: 0.2860 - accuracy: 0.9192 - val_loss: 0.3208 - val_accuracy: 0.9018 - 11s/epoch - 11ms/step
# Epoch 97/100
# 1000/1000 - 10s - loss: 0.2859 - accuracy: 0.9180 - val_loss: 0.3206 - val_accuracy: 0.9018 - 10s/epoch - 10ms/step
# Epoch 98/100
# 1000/1000 - 10s - loss: 0.2845 - accuracy: 0.9178 - val_loss: 0.3192 - val_accuracy: 0.9025 - 10s/epoch - 10ms/step
# Epoch 99/100
# 1000/1000 - 10s - loss: 0.2827 - accuracy: 0.9197 - val_loss: 0.3183 - val_accuracy: 0.9025 - 10s/epoch - 10ms/step
# Epoch 100/100
#
# Epoch 100: saving model to training/cp-0100.ckpt
# 1000/1000 - 10s - loss: 0.2815 - accuracy: 0.9186 - val_loss: 0.3184 - val_accuracy: 0.9018 - 10s/epoch - 10ms/step

# %% [markdown]
# ### Save the entire model

# %%
model.save('model/sentiment_model_v1')
# Out:
# INFO:tensorflow:Assets written to: model/sentiment_model_v1/assets
# INFO:tensorflow:Assets written to: model/sentiment_model_v1/assets

# %% [markdown]
# ### Plot accuracy and loss during training

# %%
def plot_history(history, name):
  plt.plot(history.history[name])
  plt.plot(history.history['val_'+name])
  plt.xlabel("Epochs")
  plt.ylabel(name)
  plt.legend([name, 'val_'+name])
  plt.show()

# %%
plot_history(history, "accuracy")
plot_history(history, "loss")

# %% [markdown]
# ### Evaluate the model

# %%
model.evaluate(testing_padded, testing_labels, verbose=2)
# Out:
# 313/313 - 1s - loss: 0.8839 - accuracy: 0.6521 - 562ms/epoch - 2ms/step
# [0.883934497833252, 0.6521000266075134]

# %% [markdown]
# ### Make predictions

# %%
sentences = ["I recently watched it, and it's absolutely fantastic. The acting, direction, and storytelling are all top-notch. I highly recommend it.", 
             "I watched it and was let down. The acting felt flat, and the story was uninspiring. I wouldn't recommend it."]
sequences = tokenizer.texts_to_sequences(sentences)
padded = pad_sequences(sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)
print(model.predict(padded))
# Out:
# 1/1 [==============================] - 0s 20ms/step
# [[0.7700121 ]
#  [0.31945133]]

# %% [markdown]
# seems to work

# %% [markdown]
# ### Visualizing the Embeddings

# %% [markdown]
# To visualize the embeddings we use this tool: https://projector.tensorflow.org/
#
# This tool requires 2 inpiut file:
#
#     * TSV file for the vectors
#     * TSV file for metadata (optional)

# %%
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

# %%
e = model.layers[0]
weights = e.get_weights()[0]

# %%
out_v = io.open('data/vector.tsv', 'w', encoding='utf-8')
out_m = io.open('data/metadata.tsv', 'w', encoding='utf-8')

for word_num in range(1, vocab_size):
  word = reverse_word_index[word_num]
  embeddings = weights[word_num]
  out_m.write(word + "\n")
  out_v.write('\t'.join([str(x) for x in embeddings]) + "\n")
    
out_v.close()
out_m.close()

# %% [markdown]
# ### This is the result for the embedding

# %% [markdown]
# ![image.png](attachment:image.png)
